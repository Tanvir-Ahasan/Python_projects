# %%
import pandas as pd

# %%
url= 'https://en.wikipedia.org/wiki/Wikipedia:Fundraising_statistics'

# %%
tb=pd.read_html(url)

# %%
tb[0].head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570

# %%
fundraising=tb[0]

# %%
fundraising ["REV"]= fundraising["Revenue"].str[2:]
fundraising ["REV"]= fundraising["REV"].str.replace (",", "")

# %%
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          REV
# 0  154686521
# 1  162886686
# 2  129234327
# 3  120067266
# 4  104505783

# %%
fundraising ["REV"]=pd.to_numeric(fundraising ["REV"])

# %%
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          REV
# 0  154686521
# 1  162886686
# 2  129234327
# 3  120067266
# 4  104505783

# %%
 fundraising ["EXE"]= fundraising["Expenses"].str[2:]
fundraising ["EXE"]= fundraising["EXE"].str.replace (",", "")

# %%
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          REV        EXE
# 0  154686521  145970915
# 1  162886686  111839819
# 2  129234327  112489397
# 3  120067266   91414010
# 4  104505783   81442265

# %%
fundraising ["EXE"]=pd.to_numeric(fundraising ["EXE"])

# %%
fundraising["profit"]= fundraising ["REV"] - fundraising ["EXE"]

# %%
fundraising=fundraising.drop("Revenue" ,axis=1 )

# %%
fundraising=fundraising.drop("Expenses" ,axis=1 )

# %%
fundraising.head()
# Out:
#       Year Source    Asset rise   Total assets        REV        EXE    profit
# 0  2021/22    PDF   $ 8,173,996  $ 239,351,532  154686521  145970915   8715606
# 1  2020/21    PDF  $ 50,861,811  $ 231,177,536  162886686  111839819  51046867
# 2  2019/20    PDF  $ 14,674,300  $ 180,315,725  129234327  112489397  16744930
# 3  2018/19    PDF  $ 30,691,855  $ 165,641,425  120067266   91414010  28653256
# 4  2017/18    PDF  $ 21,619,373  $ 134,949,570  104505783   81442265  23063518
